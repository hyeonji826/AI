# %% [markdown]
# ## 1. CUDA & NVIDIA 드라이버 확인
# - 최신 드라이버와 CUDA Toolkit 설치 권장
# - 드라이버 버전 확인
# - CUDA Version이 11.x 또는 12.x로 나오면 OK
#
# ```r
# nvidia-smi
# ```
#
# 만약 nvidia-smi 명령이 인식되지 않으면 [NVIDIA 공식 드라이버](https://www.nvidia.com/en-us/drivers/)에서 최신 드라이버를 설치해주세요.

# %% [markdown]
# ## 2. Python + 가상환경 설치

# %% [markdown]
# ### 1. Python 3.11 ~ 설치 권장
#
# [공식 다운로드](https://www.python.org/downloads/windows/)

# %% [markdown]
# ### 2. 가상환경 생성 (CMD 또는 VSCode 터미널에서)
#
# ```r
# python -m venv venv
# .\venv\Scripts\activate
# ```

# %% [markdown]
# ### 3. PyTorch 설치 (CUDA 지원)
# 공식 사이트에서 명령어 생성
# https://pytorch.org/get-started/locally/
#
# - OS: Windows
# - Package: pip
# - Language: Python
# - Compute Platform: CUDA 12.1 (또는 드라이버와 맞는 CUDA)
#
# ```r
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# ```

# %% [markdown]
# ### 4. 설치 확인
#
# ```r
# import torch
#
# print(torch.__version__)              # 설치된 버전 확인
# print(torch.cuda.is_available())      # True면 GPU 사용 가능
# print(torch.cuda.get_device_name(0))
# ```
