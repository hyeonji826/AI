# %% [markdown]
# ## 1. 이안류 CCTV 데이터셋
#
# ​AI Hub의 '이안류 CCTV 데이터'는 우리나라 주요 해수욕장(해운대, 송정, 대천, 중문, 낙산)에서 이안류 발생 여부와 위치를 모니터링하기 위해 구축된 인공지능 학습용 데이터셋입니다. 해수욕장 주변에 설치된 CCTV 영상을 이미지로 변환하여, 이안류 발생 여부와 위치를 가시화하는 모델 개발에 활용할 수 있습니다. 이 데이터셋은 이안류 탐지 및 예측 시스템 개발에 필수적인 자료를 제공하며, 해수욕객의 안전을 위한 응용 서비스 구성에 활용될 수 있습니다. ​이안류는 해안에서 먼 바다로 빠르게 이동하는 폭이 좁은 바닷물의 흐름으로, 기상 상태가 양호한 경우에도 나타나며, 얕은 곳에 있던 해수욕객을 순식간에 수심이 깊은 먼 바다로 이동시켜 인명사고를 유발할 수 있습니다. 따라서 이러한 데이터셋은 해수욕장 안전 관리 및 이안류 예측 모델 개발에 중요한 역할을 합니다.
#
# 아래 AIHub에서 이안류 CCTV 데이터셋을 다운로드 받습니다.
#
# https://www.aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=data&dataSetSn=71297
#
# ```
# !pip install ultralytics opencv-python
# ```

# %%
# !unzip -q /content/ripcurrent.zip

# %%
# !pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.176-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.176-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.176 ultralytics-thop-2.0.15

# %%
import os
import random
import shutil
import cv2
import glob
import json
import yaml
import ultralytics
import matplotlib.pyplot as plt
from torchvision import transforms
# 반복되는 구문에 쓰면 얼마나 진행됐는지 알 수 있음
from tqdm import tqdm
from ultralytics import YOLO
# 이미지 어노테이션 자동화
from ultralytics.utils.plotting import Annotator
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.2/112.6 GB disk)

# %%
data_root = '/content'
file_root = f"{data_root}/Sample"

train_root = f'{data_root}/train'
valid_root = f'{data_root}/valid'
test_root = f'{data_root}/test'

# 단순 폴더만 만듦
for folder in [train_root,valid_root,test_root]:
    if not os.path.exists(folder):
        os.makedirs(folder)
    for s in ['images','labels']:
        s_folder = f"{folder}/{s}"
        if not os.path.exists(s_folder):
            os.makedirs(s_folder)

# %%
file_list = glob.glob(f'{file_root}/02.라벨링데이터/*.json')
file_list
# Out:
# ['/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090251.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133806.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090627.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090249.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091320.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182824.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144822.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133731.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182805.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091049.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090932.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090250.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090204.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091002.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133730.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090215.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133740.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090930.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144651.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090436.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182820.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090923.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161821.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091322.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182835.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161834.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144631.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161832.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144935.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133814.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133754.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090833.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133741.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144730.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091714.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133809.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161814.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161813.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090908.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090224.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090439.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090615.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090835.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161825.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091619.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090403.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092109.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090130.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144706.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091425.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091324.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182827.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090931.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090431.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144625.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090213.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091114.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090843.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090434.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091235.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091321.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091239.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144659.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144707.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091615.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090159.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144709.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090407.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144705.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090423.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_091019.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145113.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092111.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133750.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090456.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182804.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090216.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144937.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145001.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090958.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133753.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091422.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161833.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090956.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090435.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091713.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091003.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133746.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091241.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091009.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090832.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182814.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091129.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144655.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182809.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090405.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090645.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144849.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091008.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090154.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091428.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091002.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091055.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161819.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090356.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133808.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133739.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133807.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144700.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182821.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091010.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161811.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144728.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145045.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091715.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091128.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090839.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091111.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161816.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090153.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182815.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091358.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090907.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090357.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161809.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090205.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090641.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144712.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092114.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144801.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090203.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090838.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144626.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182833.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144653.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091010.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144710.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144847.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090841.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091243.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090433.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144701.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133813.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161804.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090440.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090415.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144628.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090718.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091053.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182838.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091727.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091401.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144802.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133744.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090438.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090354.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161812.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133734.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091427.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091710.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090214.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144915.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144848.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091130.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091724.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144629.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090404.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091236.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090617.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090425.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091612.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090402.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144708.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182803.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161826.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091613.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182818.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090158.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182830.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133802.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144627.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145115.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092108.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091323.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090907.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182831.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090216.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161828.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182802.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144657.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144844.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091047.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090432.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090218.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090623.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182826.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090442.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133812.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090204.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144652.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090410.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090152.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091242.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161831.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090910.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161823.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145006.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090928.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091233.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133810.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144710.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091359.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091219.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090644.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182816.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145114.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090253.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090836.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091000.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144823.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161822.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090912.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090419.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161824.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091058.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161836.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144630.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091003.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144703.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144702.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161818.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090840.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091008.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161810.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090414.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090717.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090416.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144916.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090212.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144638.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090829.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144845.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144656.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090642.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133801.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091709.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182808.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091005.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090417.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091218.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090528.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091220.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161800.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145121.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133748.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090833.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092107.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090400.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090201.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144704.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090922.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144729.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090842.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091426.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182829.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182825.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091113.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091423.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091725.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133742.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161815.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090716.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182807.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091001.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090430.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133737.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182810.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090616.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133736.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091007.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133733.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144634.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091617.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090834.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_091021.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_091221.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133743.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091001.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182801.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090618.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090417.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090624.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090247.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182822.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144936.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182812.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090719.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091110.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090255.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090714.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090925.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091007.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090215.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182828.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161837.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091115.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090926.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091711.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182819.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144635.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090844.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090427.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144918.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144654.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE1_20190712_144633.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090254.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090720.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090831.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090845.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133752.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090415.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090909.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091728.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091712.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091052.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090426.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091006.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090412.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092115.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090252.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161829.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161820.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090427.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161807.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133811.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090646.json',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091112.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091419.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA2_20190701_182811.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090846.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090420.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161801.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091006.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090715.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090406.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091056.json',
#  '/content/Sample/02.라벨링데이터/DC_MUDCH_20190705_133738.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145035.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091046.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090911.json',
#  '/content/Sample/02.라벨링데이터/JM_BADA1_20190701_161802.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090457.json',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091421.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144846.json',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090526.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090927.json',
#  '/content/Sample/02.라벨링데이터/DC_ZIPTR_20190705_090409.json',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144852.json',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090452.json',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090928.json']

# %%
# yolo 쓰기 위해 json파일을 yolo의 bbox 형식으로 바꿔줘야함
def json_to_yolo_bbox(bbox,w,h):
    # xcenter = xmin, xmax / 2
    # ycenter = ymin, ymax / 2
    # print(bbox)
    x_center = ((bbox[0][0]) + (bbox[1][0])) / 2 / w
    # print(x_center)
    y_center = ((bbox[0][1]) + (bbox[3][1])) / 2 / h
    # print(y_center)

    width = (bbox[1][0] - bbox[0][0]) / w
    height = (bbox[3][1] - bbox[0][1]) / h

    return [x_center,y_center,width,height]

# %%
file = file_list[156]
print(file)
# Out:
# /content/Sample/02.라벨링데이터/JM_BADA1_20190701_161812.json

# %%
# Bounding Box 형태를 YOLO 포멧으로 변환하기
result = set()
with open(file,'r') as f:
    json_data = json.load(f)
    width, height = list(map(int,json_data['image_info']['resolution'].split(',')))  # bbox 안의 해상도에 나와있는 너비 높이를 int로 넣음
    cls = 0

    if json_data['annotations'].get("drawing"):
        for b in json_data["annotations"]['drawing']:
            yolo_bbox = json_to_yolo_bbox(b,width,height)
            bbox_string = ' '.join([str(x) for x in yolo_bbox])
            # print(bbox_string
            result.add(f"{cls} {bbox_string}")

# %%
# 실제 좌표 X -> 정규화된 좌표
result = list(result)
result
# Out:
# []

# %%
if result:
    with open(file.replace('json','txt'), 'w', encoding='utf-8') as t:
        t.write('\n'.join(result))
        print(file)

# %%
for file in tqdm(file_list):
    result = set()
    with open(file, 'r') as f:
        json_data = json.load(f)
        width, height = list(map(int, json_data["image_info"]["resolution"].split(',')))
        cls = 0
        num_b = json_data["annotations"]['bounding_count']

        if num_b > 0 :
            for b in json_data["annotations"]['drawing']:
                yolo_bbox = json_to_yolo_bbox(b,width,height)
                bbox_string = ' '.join([str(x) for x in yolo_bbox])
                # print(bbox_string
                result.add(f"{cls} {bbox_string}")
            result = list(result)

            if result:
                with open(file.replace('json','txt'), 'w', encoding='utf-8') as t:
                    t.write('\n'.join(result))
# Out:
# 100%|██████████| 360/360 [00:00<00:00, 2295.99it/s]

# %%
random.seed(2025)
file_list = glob.glob(f'{file_root}/02.라벨링데이터/*.txt')

random.shuffle(file_list)
test_ratio = 0.1
num_file = len(file_list)
num_file
# Out:
# 240

# %%
test_list = file_list[:int(num_file*test_ratio)]
valid_list = file_list[int(num_file*test_ratio):int(num_file*test_ratio)*2]
train_list = file_list[int(num_file*test_ratio)*2:]

# %%
test_list
# Out:
# ['/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092111.txt',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_091239.txt',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_144936.txt',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091727.txt',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091001.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090526.txt',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_090907.txt',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_092107.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090224.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091003.txt',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090357.txt',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090930.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090214.txt',
#  '/content/Sample/02.라벨링데이터/HD_PARA1_20190607_091053.txt',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090841.txt',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_090415.txt',
#  '/content/Sample/02.라벨링데이터/HD_SEAC1_20190607_091725.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090215.txt',
#  '/content/Sample/02.라벨링데이터/NS_NSBE2_20190712_145035.txt',
#  '/content/Sample/02.라벨링데이터/SJ_SJHT1_20190607_091021.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_091006.txt',
#  '/content/Sample/02.라벨링데이터/SJ_WHIB1_20190617_090617.txt',
#  '/content/Sample/02.라벨링데이터/HD_PARA2_20190630_090845.txt',
#  '/content/Sample/02.라벨링데이터/HD_GLORY_20190607_090216.txt']

# %%
# /content/Sample/02.라벨링데이터/HD_GLORY_20190607_090832.txt
for i in tqdm(test_list):
    txt_name = i.split('/')[-1]     # 파일 이름이 들어감
    shutil.copy(i, f'{test_root}/labels/{txt_name}')
    img_path = i.replace('02.라벨링데이터','01.원천데이터').replace('txt','jpg')
    # /content/Sample/02.라벨링데이터/HD_GLORY_20190607_090832.txt
    # 1. /content/Sample/01.원천데이터/HD_GLORY_20190607_090832.txt
    # 2. /content/Sample/01.원천데이터/HD_GLORY_20190607_090832.jpg
    img_name = img_path.split('/')[-1]
    shutil.copyfile(img_path, f'{test_root}/images/{img_name}')
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 394.41it/s]

# %%
for i in tqdm(valid_list):
    txt_name = i.split('/')[-1]
    shutil.copy(i, f'{valid_root}/labels/{txt_name}')
    img_path = i.replace('02.라벨링데이터','01.원천데이터').replace('txt','jpg')
    img_name = img_path.split('/')[-1]
    shutil.copyfile(img_path, f'{valid_root}/images/{img_name}')
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 421.40it/s]

# %%
for i in tqdm(train_list):
    txt_name = i.split('/')[-1]     # 파일 이름이 들어감
    shutil.copy(i, f'{train_root}/labels/{txt_name}')
    img_path = i.replace('02.라벨링데이터','01.원천데이터').replace('txt','jpg')
    img_name = img_path.split('/')[-1]
    shutil.copyfile(img_path, f'{train_root}/images/{img_name}')
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 710.86it/s]

# %%
import yaml
data = dict()

data['train'] = train_root
data['val'] = valid_root
data['test'] = test_root
data['nc'] = 1
data['names'] = ['yes']

with open(f'ripcurrent.yaml','w') as f:
    yaml.dump(data,f)

# %%
# 모델 불러오기 & 학습 Setting하기
model = YOLO('yolov8s.pt')
# patience : epoch 30번 이상 loss값이 좋아지지 않으면 멈춰라!
results= model.train(data = 'ripcurrent.yaml', epochs = 10, batch = 8, imgsz = 224, device = 0, workers = 2, amp= False, patience = 30, name = 'rip_s')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100%|██████████| 21.5M/21.5M [00:01<00:00, 15.8MB/s]
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=ripcurrent.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=rip_s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/rip_s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100%|██████████| 755k/755k [00:00<00:00, 35.4MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2017.8±701.0 MB/s, size: 129.8 KB)
# train: Scanning /content/train/labels... 192 images, 0 backgrounds, 0 corrupt: 100%|██████████| 192/192 [00:00<00:00, 789.46it/s]
# train: New cache created: /content/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 925.0±666.4 MB/s, size: 123.3 KB)
# val: Scanning /content/valid/labels... 24 images, 0 backgrounds, 0 corrupt: 100%|██████████| 24/24 [00:00<00:00, 1895.62it/s]
# val: New cache created: /content/valid/labels.cache
# Plotting labels to runs/detect/rip_s/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/detect/rip_s
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10     0.688G      3.306      5.109      2.034          8        224: 100%|██████████| 24/24 [00:05<00:00,  4.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
#                    all         24         27       0.43      0.148      0.145     0.0534
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10     0.723G        2.6      2.231      1.621         10        224: 100%|██████████| 24/24 [00:02<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 13.32it/s]
#                    all         24         27      0.377      0.444      0.285     0.0759
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      0.76G      2.281      1.822      1.469          9        224: 100%|██████████| 24/24 [00:02<00:00, 10.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 13.61it/s]
#                    all         24         27      0.362      0.185      0.242     0.0829
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10     0.844G      2.235      1.724      1.501          9        224: 100%|██████████| 24/24 [00:03<00:00,  6.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.87it/s]
#                    all         24         27      0.303      0.296      0.235     0.0904
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10     0.912G      2.288       1.46      1.444         11        224: 100%|██████████| 24/24 [00:02<00:00, 10.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.56it/s]
#                    all         24         27      0.324       0.37      0.277      0.138
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      1.01G      2.196      1.536      1.406          8        224: 100%|██████████| 24/24 [00:02<00:00, 10.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
#                    all         24         27      0.717      0.564       0.68       0.25
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      1.05G      1.947      1.357      1.321          8        224: 100%|██████████| 24/24 [00:02<00:00, 10.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.23it/s]
#                    all         24         27      0.481      0.481      0.408      0.183
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      1.15G      1.905      1.275      1.261          9        224: 100%|██████████| 24/24 [00:03<00:00,  7.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.24it/s]
#                    all         24         27      0.684      0.721      0.697      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      1.19G      1.856      1.198      1.277          8        224: 100%|██████████| 24/24 [00:02<00:00, 10.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.75it/s]
#                    all         24         27      0.698      0.519      0.633      0.288
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      1.29G      1.755      1.125      1.242          8        224: 100%|██████████| 24/24 [00:02<00:00, 10.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  7.36it/s]
#                    all         24         27      0.597      0.667      0.674      0.289
# 10 epochs completed in 0.011 hours.
# Optimizer stripped from runs/detect/rip_s/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/rip_s/weights/best.pt, 22.5MB
#
# Validating runs/detect/rip_s/weights/best.pt...
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.76it/s]
#                    all         24         27      0.683       0.72      0.697      0.317
# Speed: 0.1ms preprocess, 3.1ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/rip_s

# %%
result_folder = f'runs/detect/rip_s'

# %%
model = YOLO(f'{result_folder}/weights/best.pt')
metrics = model.val(split='test')

print(metrics.box.map)
print(metrics.box.map50)

# 0.25763015334580885
# 0.5842591088307725
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2108.8±577.5 MB/s, size: 147.2 KB)
# val: Scanning /content/test/labels... 24 images, 0 backgrounds, 0 corrupt: 100%|██████████| 24/24 [00:00<00:00, 2173.07it/s]
# val: New cache created: /content/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.88it/s]
#                    all         24         25      0.683      0.602      0.584      0.258
# Speed: 0.2ms preprocess, 12.6ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/val
# 0.25763015334580885
# 0.5842591088307725

# %%
test_root = f'{data_root}/test'
test_file_list = glob.glob(f'{test_root}/images/*')
random.shuffle(test_file_list)

# %%
# 모델 불러오기
model = YOLO(f'{result_folder}/weights/best.pt')

test_data_transform = transforms.Compose([transforms.ToTensor()])

color_dict = [(0, 0, 255)]

# %%
# Inference 진행하기
test_img = cv2.imread(test_file_list[0])    # BGR
img_src = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB) # RGB로 바꾸기
results = model(img_src)
# Out:
# 0: 128x224 1 yes, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 3.6ms postprocess per image at shape (1, 3, 128, 224)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'yes'}
#  obb: None
#  orig_img: array([[[ 82,  81,  86],
#          [ 82,  81,  86],
#          [ 82,  81,  89],
#          ...,
#          [108, 111, 128],
#          [108, 111, 128],
#          [108, 111, 128]],
#
#         [[ 82,  81,  86],
#          [ 82,  81,  86],
#          [ 82,  81,  89],
#          ...,
#          [108, 111, 128],
#          [108, 111, 128],
#          [108, 111, 128]],
#
#         [[ 82,  81,  86],
#          [ 82,  81,  86],
#          [ 81,  80,  88],
#          ...,
#          [108, 111, 128],
#          [108, 111, 128],
#          [108, 111, 128]],
#
#         ...,
#
#         [[ 43,  38,  42],
#          [ 43,  38,  42],
#          [ 43,  39,  40],
#          ...,
#          [ 86,  79,  61],
#          [ 86,  79,  61],
#          [ 86,  79,  61]],
#
#         [[ 38,  33,  37],
#          [ 41,  36,  40],
#          [ 43,  39,  40],
#          ...,
#          [ 86,  79,  61],
#          [ 86,  79,  61],
#          [ 86,  79,  61]],
#
#         [[ 34,  29,  33],
#          [ 38,  33,  37],
#          [ 42,  38,  39],
#          ...,
#          [ 86,  79,  61],
#          [ 86,  79,  61],
#          [ 86,  79,  61]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: 'image0.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.062962000081825, 'inference': 11.488094000014826, 'postprocess': 3.6127820001183863}]

# %%
results[0].boxes # 시각화에 xyxy 쓴다!
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3542], device='cuda:0')
# data: tensor([[1.1922e+03, 4.2230e+02, 1.4388e+03, 5.9308e+02, 3.5422e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1315.5103,  507.6895,  246.5245,  170.7744]], device='cuda:0')
# xywhn: tensor([[0.6852, 0.4701, 0.1284, 0.1581]], device='cuda:0')
# xyxy: tensor([[1192.2479,  422.3023, 1438.7725,  593.0767]], device='cuda:0')
# xyxyn: tensor([[0.6210, 0.3910, 0.7494, 0.5491]], device='cuda:0')

# %%
test_img = cv2.imread(test_file_list[0])
img_src = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
results = model(img_src)[0]
# Out:
# 0: 128x224 1 yes, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.5ms postprocess per image at shape (1, 3, 128, 224)

# %%
annotator = Annotator(img_src)
boxes = results.boxes
boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3542], device='cuda:0')
# data: tensor([[1.1922e+03, 4.2230e+02, 1.4388e+03, 5.9308e+02, 3.5422e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1315.5103,  507.6895,  246.5245,  170.7744]], device='cuda:0')
# xywhn: tensor([[0.6852, 0.4701, 0.1284, 0.1581]], device='cuda:0')
# xyxy: tensor([[1192.2479,  422.3023, 1438.7725,  593.0767]], device='cuda:0')
# xyxyn: tensor([[0.6210, 0.3910, 0.7494, 0.5491]], device='cuda:0')

# %%
for box in boxes:
    b = box.xyxy[0]
    cls = box.cls
    # [x_min, y_min, x_max, y_max]
    annotator.box_label(b, model.names[int(cls)], color_dict[int(cls)])
img_src = annotator.result()
plt.imshow(img_src)
plt.show()

# %%
plt.figure(figsize = (12,6))
for idx in range(6):
    test_img = cv2.imread(test_file_list[idx])
    img_src = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
    results = model(test_img)

    for result in results:
        annotator = Annotator(img_src)
        boxes = result.boxes
        for box in boxes:
            b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
            cls = box.cls
            annotator.box_label(b, model.names[int(cls)], color_dict[int(cls)])
    img_src = annotator.result()

    plt.subplot(2, 3, (idx+1))
    plt.imshow(img_src)
plt.show()
# Out:
# 0: 128x224 1 yes, 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 9.3ms postprocess per image at shape (1, 3, 128, 224)
#
# 0: 128x224 1 yes, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 128, 224)
#
# 0: 128x224 1 yes, 14.1ms
# Speed: 1.1ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 128, 224)
#
# 0: 128x224 2 yess, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 224)
#
# 0: 128x224 2 yess, 17.8ms
# Speed: 1.1ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 128, 224)
#
# 0: 128x224 2 yess, 11.2ms
# Speed: 0.9ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 128, 224)
